# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
# %matplotlib inline

# %%
# Read the 'Advertising.csv' dataset
data_filename = 'Advertising.csv'

# Read data file using pandas libraries
df = pd.read_csv(data_filename)

# %%
# Take a quick look at the data
df.head(20)
# Out:
#        TV  Radio  Sales
# 0   230.1   37.8   22.1
# 1    44.5   39.3   10.4
# 2    17.2   45.9    9.3
# 3   151.5   41.3   18.5
# 4   180.8   10.8   12.9
# 5     8.7   48.9    7.2
# 6    57.5   32.8   11.8
# 7   120.2   19.6   13.2
# 8     8.6    2.1    4.8
# 9   199.8    2.6   10.6
# 10   66.1    5.8    8.6
# 11  214.7   24.0   17.4
# 12   23.8   35.1    9.2
# 13   97.5    7.6    9.7
# 14  204.1   32.9   19.0
# 15  195.4   47.7   22.4
# 16   67.8   36.6   12.5
# 17  281.4   39.6   24.4
# 18   69.2   20.5   11.3
# 19  147.3   23.9   14.6

# %%
# Assign TV advertising as predictor variable/ design matrix 'X' 
X = np.array(df['TV'])
X=X.reshape(-1,1)
#

# Assign sales as response variable 'y'
y =np.array(df['Sales'])
# Out:
# 2

# %%
# Split the dataset in training and testing with 80% training set 
# & set random state to 310 for reproducable results 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=310)

# %%
# Run the cell below to plot the data
plt.figure(figsize=(7,5))
plt.scatter(X_train, y_train, edgecolor = 'k',label='training set',color = '#B9D6D6',s=45)
plt.scatter(X_test, y_test, edgecolor = 'k',label='test set',color = 'darkblue',s=50)
plt.xlabel('TV',fontsize=16)
plt.ylabel('Sales',fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
#  Now that the data is set up properly use the sklearn 'LinearRegression' class to fit on the training set.

# %%
# Declare a class instance of LinearRegression and assign it to model
model =LinearRegression()
# Call the 'fit' method on the training data
model.fit(X_train,y_train)

# Predict on the test set using the 'predict' method
y_pred_test =model.predict(X_test)

# %%
### edTest(test_mse) ###
# Compute the MSE on the test set with the predicted values and print it
mse = mean_squared_error(y_test, y_pred_test)
print(f'The test MSE is {mse}')
# Out:
# The test MSE is 8.14547585895561

# %%
# Make a plot of the data along with the predicted linear regression
plt.figure(figsize=(7,5))
plt.scatter(X_train, y_train, edgecolor = 'k',label='training set',color = '#B9D6D6',s=45)
plt.scatter(X_test, y_test, edgecolor = 'k',label='test set',color = 'darkblue',s=50)
plt.plot(X_test, y_pred_test, label='model',color = '#E44E47',lw=2)
plt.xlabel('TV',fontsize=16)
plt.ylabel('Sales',fontsize=16)
plt.legend(fontsize=16)

# %% [markdown]
# ### ⏸ Rerun your code but change the training size to 60%. Did your test `MSE` increase, or decrease?
#
# #### A. Test MSE increased
# #### B. Test MSE decreased
# #### C. There was no change in the test MSE

# %%
### edTest(test_chow1) ###
# Submit an answer choice as a string below 
# (eg. if you choose option A, put 'A')
answer1 = 'A'
