# %%
 a= {i: i * i for i in range(6)} 
print(a)

# %%
list1 = ["Python", "for", "data", "science"]
print([(i,e) for i,e in enumerate(list1)])
print([(i,e) for i,e in enumerate(list1, start =1)])

# %%
def func(a=10, b, c=7):
    return b+c
    
func(1, c=2)

# %%
def fact(n):
  if n<=0:
    return 1
  else:
    return fact(n-1)*n
fact(3)

# %%
def func1(name, age):
    print(name, age)
func1(name="joe",23)

# %%
def outer_func(a, b):
    def inner_func(c, d):
        return c + d

    return inner_func(a, b)
    return a

result = outer_func(6, 14)
print(result)
